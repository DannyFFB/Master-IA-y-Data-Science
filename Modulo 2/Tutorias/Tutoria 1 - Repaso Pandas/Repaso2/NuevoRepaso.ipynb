# %%
import pandas as pd
df= pd.read_csv("clean_jobs.csv")

# %%
df.isnull().sum()
# Out:
# id                   0
# title                0
# company              0
# location             0
# link                 0
# source               0
# date_posted          0
# work_type          327
# employment_type    327
# description          0
# dtype: int64

# %%
df["work_type"].fillna("Unknown", inplace=True)
df["employment_type"].fillna("Unknown", inplace=True)
# Out:
# C:\Users\danny\AppData\Local\Temp\ipykernel_9020\588936517.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["employment_type"].fillna("Unknown", inplace=True)
# C:\Users\danny\AppData\Local\Temp\ipykernel_9020\588936517.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df["employment_type"].fillna("Unknown", inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327 entries, 0 to 326
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               327 non-null    int64
#  1   title            327 non-null    object
#  2   company          327 non-null    object
#  3   location         327 non-null    object
#  4   link             327 non-null    object
#  5   source           327 non-null    object
#  6   date_posted      327 non-null    object
#  7   work_type        327 non-null    object
#  8   employment_type  327 non-null    object
#  9   description      327 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 25.7+ KB

# %%
df.drop("description", axis=1 , inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327 entries, 0 to 326
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               327 non-null    int64
#  1   title            327 non-null    object
#  2   company          327 non-null    object
#  3   location         327 non-null    object
#  4   source           327 non-null    object
#  5   date_posted      327 non-null    object
#  6   work_type        327 non-null    object
#  7   employment_type  327 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 20.6+ KB

# %%
df
# Out:
#       id                          title                 company  \
# 0      1                   Data Analyst                    Meta
# 1      2                   Data Analyst                    Meta
# 2      3                   Data Analyst                    Meta
# 3      4                   Data Analyst                    Meta
# 4      5                Data Analyst II               Pinterest
# ..   ...                            ...                     ...
# 322  691  Data Engineer- Python Pyspark                 Virtusa
# 323  692     Data Engineer with Pyspark               Cognizant
# 324  693                  Data Engineer  Mercedes-Benz Malaysia
# 325  740                Data Engineer I                IntePros
# 326  741                  Data Engineer               Snap Inc.
#
#                               location    source date_posted work_type  \
# 0                         New York, NY  LinkedIn  2025-04-14   Unknown
# 1                    San Francisco, CA  LinkedIn  2025-04-14   Unknown
# 2                      Los Angeles, CA  LinkedIn  2025-04-14   Unknown
# 3                       Washington, DC  LinkedIn  2025-04-14   Unknown
# 4                          Chicago, IL  LinkedIn  2025-04-16   Unknown
# ..                                 ...       ...         ...       ...
# 322         Chennai, Tamil Nadu, India  LinkedIn  2025-04-10   Unknown
# 323  Bangalore Urban, Karnataka, India  LinkedIn  2025-04-13   Unknown
# 324        Puchong, Selangor, Malaysia  LinkedIn  2025-04-16   Unknown
# 325                        Seattle, WA  LinkedIn  2025-04-15   Unknown
# 326                       Bellevue, WA  LinkedIn  2025-04-16   Unknown
#
#     employment_type
# 0           Unknown
# 1           Unknown
# 2           Unknown
# 3           Unknown
# 4           Unknown
# ..              ...
# 322         Unknown
# 323         Unknown
# 324         Unknown
# 325         Unknown
# 326         Unknown
#
# [327 rows x 8 columns]

# %%
df["source"].value_counts()
# Out:
# source
# LinkedIn    327
# Name: count, dtype: int64

# %%
df["company"].value_counts()
# Out:
# company
# Meta                57
# Google              12
# Netflix             11
# Amazon              10
# Pinterest            5
#                     ..
# Procter & Gamble     1
# Morgan Stanley       1
# tiket.com            1
# Virtusa              1
# IntePros             1
# Name: count, Length: 193, dtype: int64

# %%
df.sort_values("date_posted")
# Out:
#       id                                      title  \
# 41    77                      Business Data Analyst
# 309  673                              Data Engineer
# 306  670                              Data Engineer
# 34    70           Data Analyst Intern (Fall start)
# 35    71                Analyst, Data Science, RMBS
# ..   ...                                        ...
# 145  406                     Data Scientist/Analyst
# 142  403  Staff Data Scientist, Strategy & Insights
# 223  578              Data Engineer (L4) - Security
# 101  214                               Data Analyst
# 102  235                               Data Analyst
#
#                             company  \
# 41                      LTIMindtree
# 309              Ford Motor Company
# 306                         Chevron
# 34                             AARP
# 35      Cerberus Capital Management
# ..                              ...
# 145  Sony Interactive Entertainment
# 142                        LinkedIn
# 223                         Netflix
# 101                        Artefact
# 102                      TEKsystems
#
#                                          location    source date_posted  \
# 41                                Jersey City, NJ  LinkedIn  2025-04-10
# 309                    Chennai, Tamil Nadu, India  LinkedIn  2025-04-10
# 306  Manila, National Capital Region, Philippines  LinkedIn  2025-04-10
# 34                                 Washington, DC  LinkedIn  2025-04-10
# 35                                   New York, NY  LinkedIn  2025-04-10
# ..                                            ...       ...         ...
# 145                Dublin, County Dublin, Ireland  LinkedIn  2025-04-17
# 142                                 Sunnyvale, CA  LinkedIn  2025-04-17
# 223                                 Los Gatos, CA  LinkedIn  2025-04-17
# 101                                  New York, NY  LinkedIn  2025-04-17
# 102                               Santa Clara, CA  LinkedIn  2025-04-17
#
#     work_type employment_type
# 41    Unknown         Unknown
# 309   Unknown         Unknown
# 306   Unknown         Unknown
# 34    Unknown         Unknown
# 35    Unknown         Unknown
# ..        ...             ...
# 145   Unknown         Unknown
# 142   Unknown         Unknown
# 223   Unknown         Unknown
# 101   Unknown         Unknown
# 102   Unknown         Unknown
#
# [327 rows x 8 columns]

# %%
df[["title","location"]]
# Out:
#                              title                           location
# 0                     Data Analyst                       New York, NY
# 1                     Data Analyst                  San Francisco, CA
# 2                     Data Analyst                    Los Angeles, CA
# 3                     Data Analyst                     Washington, DC
# 4                  Data Analyst II                        Chicago, IL
# ..                             ...                                ...
# 322  Data Engineer- Python Pyspark         Chennai, Tamil Nadu, India
# 323     Data Engineer with Pyspark  Bangalore Urban, Karnataka, India
# 324                  Data Engineer        Puchong, Selangor, Malaysia
# 325                Data Engineer I                        Seattle, WA
# 326                  Data Engineer                       Bellevue, WA
#
# [327 rows x 2 columns]

# %%
df[:3]
# Out:
#    id         title company           location    source date_posted  \
# 0   1  Data Analyst    Meta       New York, NY  LinkedIn  2025-04-14
# 1   2  Data Analyst    Meta  San Francisco, CA  LinkedIn  2025-04-14
# 2   3  Data Analyst    Meta    Los Angeles, CA  LinkedIn  2025-04-14
#
#   work_type employment_type
# 0   Unknown         Unknown
# 1   Unknown         Unknown
# 2   Unknown         Unknown

# %%
df.iloc[[0,2],[2,4]]
# Out:
#   company    source
# 0    Meta  LinkedIn
# 2    Meta  LinkedIn

# %%
df.isna().sum()
# Out:
# id                 0
# title              0
# company            0
# location           0
# source             0
# date_posted        0
# work_type          0
# employment_type    0
# dtype: int64
